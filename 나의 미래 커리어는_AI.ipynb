# %% [markdown]
# <a href="https://colab.research.google.com/github/CornCar/OssDevLec/blob/main/%EB%82%98%EC%9D%98%20%EB%AF%B8%EB%9E%98%20%EC%BB%A4%EB%A6%AC%EC%96%B4%EB%8A%94_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 미래 커리어 예측 AI

# %% [markdown]
# 💡 1️⃣ "나의 미래 커리어 시뮬레이션 AI"
# 👉 입력된 데이터를 기반으로 미래 직업과 커리어 경로를 생성형 AI가 예측하는 모델

# %%
# prompt: 당신은 전문적인 커리어 코치 AI입니다. 학생의 학력, 스킬, 경험을 바탕으로 다음 정보를 예측하고 조언을 제공합니다.
# education_career_success.csv
# 입력 데이터:
# - 나이: {age}
# - 성별: {gender}
# - 고등학교 GPA: {high_school_gpa}
# - SAT 점수: {sat_score}
# - 대학교 랭킹: {university_ranking}
# - 대학교 GPA: {university_gpa}
# - 전공: {field_of_study}
# - 인턴십 경험: {internships_completed}개
# - 프로젝트 경험: {projects_completed}개
# - 자격증 개수: {certifications}개
# - 소프트 스킬 점수: {soft_skills_score}/10
# - 네트워킹 점수: {networking_score}/10
# 이 데이터를 바탕으로, 다음 정보를 예측하세요.
# 1. 학생이 졸업 후 받을 수 있는 평균 연봉 (USD)
# 2. 예상되는 취업 기회 (몇 개의 잡 오퍼를 받을지)
# 3. 첫 승진까지 걸리는 예상 시간
# 4. 적합한 직업 추천 (예: 데이터 사이언티스트, 마케팅 전문가, 기업가 등)
# 5. 성공을 위한 맞춤형 조언 (필요한 추가 경험, 배워야 할 기술 등)
# 출력 형식:
# -  예상 연봉: $XX,XXX
# -  추천 직업: XX
# -  첫 승진 예상 기간: X년
# -  성공을 위한 조언: XX를 배우고, XX 경험을 쌓으면 유리함.

def predict_career_success(age, gender, high_school_gpa, sat_score, university_ranking, university_gpa, field_of_study, internships_completed, projects_completed, certifications, soft_skills_score, networking_score):
  """학생의 학력, 스킬, 경험을 바탕으로 미래 커리어를 예측하고 조언을 제공합니다."""

  # (간소화된 예시) 예측 모델: 데이터를 기반으로 연봉, 취업 기회, 승진 기간, 직업 등을 예측하는 로직을 구현합니다.
  # 실제로는 머신러닝 모델을 사용하여 더 정확한 예측을 할 수 있습니다.

  # 예측 변수 초기화
  predicted_salary = 0
  predicted_job_offers = 0
  predicted_promotion_time = 0
  recommended_career = ""
  advice = ""

  # 예측 로직: 데이터를 기반으로 예측 변수를 계산합니다.
  # (예시) GPA, SAT 점수, 대학 랭킹, 인턴십, 프로젝트, 자격증, 소프트 스킬, 네트워킹 점수를 고려하여 예측
  predicted_salary = (university_gpa * 10000) + (sat_score * 50) + (internships_completed * 2000) + (projects_completed * 1000) + (certifications * 500) + (soft_skills_score * 1000) + (networking_score * 1000)

  if field_of_study == "컴퓨터 과학" and university_gpa >= 3.5 and internships_completed >= 2:
      predicted_job_offers = 5
      predicted_promotion_time = 3
      recommended_career = "데이터 사이언티스트"
      advice = "데이터 분석 및 머신러닝 기술을 배우고, 관련 분야 프로젝트 경험을 쌓으면 유리함."
  elif field_of_study == "경영학" and university_gpa >= 3.0 and networking_score >= 8:
      predicted_job_offers = 3
      predicted_promotion_time = 4
      recommended_career = "마케팅 전문가"
      advice = "비즈니스 전략 및 마케팅 전문 지식을 쌓고, 다양한 사람들과의 네트워킹을 활발하게 하면 유리함."
  else:
      predicted_job_offers = 2
      predicted_promotion_time = 5
      recommended_career = "기업가"
      advice = "창업 관련 교육 및 멘토링을 활용하고, 다양한 사업 아이디어를 구체화하는 경험을 쌓으면 유리함."

  # 예측 결과 출력
  print("-  예상 연봉: ${:,}".format(int(predicted_salary)))
  print("-  추천 직업: {}".format(recommended_career))
  print("-  첫 승진 예상 기간: {}년".format(predicted_promotion_time))
  print("-  성공을 위한 조언: {}".format(advice))

# 예시 데이터를 사용하여 예측 실행
predict_career_success(22, "남성", 3.8, 1450, 10, 3.5, "컴퓨터 과학", 2, 3, 1, 9, 7)
# Out:
# -  예상 연봉: $131,000
# -  추천 직업: 데이터 사이언티스트
# -  첫 승진 예상 기간: 3년
# -  성공을 위한 조언: 데이터 분석 및 머신러닝 기술을 배우고, 관련 분야 프로젝트 경험을 쌓으면 유리함.

# %% [markdown]
# ✅ 미래 커리어 시뮬레이션: 나의 학력, 경험을 기반으로 예상 연봉 & 직업 추천
# ✅ 맞춤형 성공 전략: 원하는 목표(연봉, 직업 만족도)에 도달하기 위해 필요한 조건 역산
# ✅ 확장 가능: Gemini AI와 함께 "추천 코스", "업계 트렌드", "네트워킹 팁" 추가 가능
